# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import zscore
data = pd.read_csv('./../datasets/data.csv')
data.head(10)
# Out:
#    age  gender  impluse  pressurehight  pressurelow  glucose     kcm  \
# 0   64       1       66            160           83    160.0    1.80
# 1   21       1       94             98           46    296.0    6.75
# 2   55       1       64            160           77    270.0    1.99
# 3   64       1       70            120           55    270.0   13.87
# 4   55       1       64            112           65    300.0    1.08
# 5   58       0       61            112           58     87.0    1.83
# 6   32       0       40            179           68    102.0    0.71
# 7   63       1       60            214           82     87.0  300.00
# 8   44       0       60            154           81    135.0    2.35
# 9   67       1       61            160           95    100.0    2.84
#
#    troponin     class
# 0     0.012  negative
# 1     1.060  positive
# 2     0.003  negative
# 3     0.122  positive
# 4     0.003  negative
# 5     0.004  negative
# 6     0.003  negative
# 7     2.370  positive
# 8     0.004  negative
# 9     0.011  negative

# %%
#count attributes and instances 
print(f'Attributes : {len(data.columns)}')
print(f'Instances : {len(data)}')
# Out:
# Attributes : 9
# Instances : 1319

# %%
columns = ['age']
outlier_percentage = {}
df = data.copy()
for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'age': 7
# Percentage of outliers in column 'age':0.53%
#
# Lower : 20.0
# Upper : 92.0
#
# Data Outlier': [ 19  19 100  14 103 103  19]

# %%
columns = ['impluse']
outlier_percentage = {}

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'impluse': 30
# Percentage of outliers in column 'impluse':2.27%
#
# Lower : 32.5
# Upper : 116.5
#
# Data Outlier': [ 135  125 1111  125  120  122  119  117  134  119  132  125  135   20
#  1111  117  132  134  119  117  135   20 1111  117  125  132  134  119
#   120  117]

# %%
columns = ['pressurehight']
outlier_percentage = {}

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'pressurehight': 32
# Percentage of outliers in column 'pressurehight':2.43%
#
# Lower : 60.5
# Upper : 192.5
#
# Data Outlier': [214 199 202 193  42 220 208 198 214 204 200 223 200 214 223 199 202 214
#  198 209 208 200 214 223 199 208 202 214 198 209 220 208]

# %%
columns = ['pressurelow']
outlier_percentage = {}

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'pressurelow': 12
# Percentage of outliers in column 'pressurelow':0.91%
#
# Lower : 33.5
# Upper : 109.5
#
# Data Outlier': [110 128 110 118 110 118 110 110 118 154 110 128]

# %%
columns = ['glucose']
outlier_percentage = {}

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'glucose': 92
# Percentage of outliers in column 'glucose':6.97%
#
# Lower : -9.25
# Upper : 276.75
#
# Data Outlier': [296. 300. 319. 301. 279. 321. 334. 392. 387. 294. 318. 322. 362. 347.
#  321. 462. 422. 382. 303. 382. 431. 368. 408. 302. 500. 541. 415. 351.
#  443. 407. 319. 290. 381. 404. 425. 366. 342. 336. 324. 346. 347. 283.
#  293. 294. 305. 338. 294. 282. 354. 277. 328. 303. 294. 391. 314. 434.
#  302. 336. 297. 406. 277. 329. 319. 285. 331. 319. 301. 279. 321. 334.
#  392. 387. 294. 318. 322. 362. 347. 321. 462. 422. 382. 303. 382. 431.
#  368. 408. 302. 500. 541. 415. 351. 443.]

# %%
columns = ['kcm']
outlier_percentage = {}

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 
#   1.48   1.47   1.5    1.29   0.959  0.218  0.937  3.21   1.31   0.817
#   2.32   1.17   1.43   0.314  3.83   1.39   1.44   2.57   1.33   0.851
#   2.12   1.6    0.298  0.91   0.407  0.999 10.     0.485  1.85   2.06
#   0.701  0.706  0.406  2.63   1.58   5.87   0.61   1.01   2.63   0.863
#   0.722  0.325  1.38   1.4    0.649  0.357  2.43   0.354  0.208  0.452
#   0.402  0.912  2.99   1.1    2.2    1.45   0.484  0.74   0.54   0.83
#   0.84   1.75   0.88   0.94   0.22   2.8    0.76   0.405  0.23   3.85
#   0.224  6.01   0.299  0.609  0.79   0.88   0.325  0.71   1.47   0.602
#   0.81  10.3    1.79  10.    10.     1.43   0.407 10.     0.553  0.549
#   0.795  0.327  1.51   2.29   2.5    1.15   0.397  0.998  1.26  10.
#   1.5    0.507  0.348  5.4    2.16   3.77   5.11   0.93   0.7    1.81
#   1.94   0.635  0.98   0.916  1.23   0.279  3.34   0.923  1.25   0.434
#   0.295  1.63   0.461 10.     1.4    0.93   1.53   1.04   0.544  0.255
#   1.37   0.45   0.263 10.     4.25   0.359  1.77 ]

# %% [markdown]
# ### 2. **Imputation**

# %%
columns = ['age']

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # find outlier
    outliers = column_data[(column_data < lower) | (column_data > upper)]

    # remove outlier
    df_no_outliers = df[(column_data >= lower) & (column_data <= upper)]
columns = ['age']
outlier_percentage = {}

for column in columns:
    column_data = df_no_outliers[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'age': 0
# Percentage of outliers in column 'age':0.00%
#
# Lower : 20.0
# Upper : 92.0
#
# Data Outlier': []

# %%
columns = ['impluse']

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # find outlier
    outliers = column_data[(column_data < lower) | (column_data > upper)]

    # remove outlier
    df_no_outliers = df[(column_data >= lower) & (column_data <= upper)]
columns = ['impluse']
outlier_percentage = {}

for column in columns:
    column_data = df_no_outliers[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'impluse': 1
# Percentage of outliers in column 'impluse':0.08%
#
# Lower : 31.5
# Upper : 115.5
#
# Data Outlier': [116]

# %%
columns = ['pressurehight']

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # find outlier
    outliers = column_data[(column_data < lower) | (column_data > upper)]

    # remove outlier
    df_no_outliers = df[(column_data >= lower) & (column_data <= upper)]
columns = ['pressurehight']
outlier_percentage = {}

for column in columns:
    column_data = df_no_outliers[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'pressurehight': 6
# Percentage of outliers in column 'pressurehight':0.47%
#
# Lower : 63.5
# Upper : 187.5
#
# Data Outlier': [192 191 192 191 192 191]

# %%
columns = ['pressurelow']

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # find outlier
    outliers = column_data[(column_data < lower) | (column_data > upper)]

    # remove outlier
    df_no_outliers = df[(column_data >= lower) & (column_data <= upper)]
columns = ['pressurelow']
outlier_percentage = {}

for column in columns:
    column_data = df_no_outliers[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'pressurelow': 1
# Percentage of outliers in column 'pressurelow':0.08%
#
# Lower : 33.75
# Upper : 107.75
#
# Data Outlier': [109]

# %%
columns = ['glucose']

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # find outlier
    outliers = column_data[(column_data < lower) | (column_data > upper)]

    # remove outlier
    df_no_outliers = df[(column_data >= lower) & (column_data <= upper)]
columns = ['glucose']
outlier_percentage = {}

for column in columns:
    column_data = df_no_outliers[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'glucose': 53
# Percentage of outliers in column 'glucose':4.32%
#
# Lower : 11.5
# Upper : 239.5
#
# Data Outlier': [270.  270.  274.  269.  251.  240.  266.  244.  241.  242.  245.  246.
#  274.  267.  256.  257.  261.  258.  276.  249.  244.  263.  271.  274.
#  240.  242.  262.  246.7 271.  252.  272.  247.  253.  276.  259.  263.
#  274.  247.  265.  250.  272.  247.  274.  269.  251.  240.  266.  244.
#  241.  242.  245.  246.  274. ]

# %%
columns = ['kcm']

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # find outlier
    outliers = column_data[(column_data < lower) | (column_data > upper)]

    # remove outlier
    df_no_outliers = df[(column_data >= lower) & (column_data <= upper)]
columns = ['kcm']
outlier_percentage = {}

for column in columns:
    column_data = df_no_outliers[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'kcm': 62
# Percentage of outliers in column 'kcm':5.57%
#
# Lower : -2.071249999999999
# Upper : 7.578749999999999
#
# Data Outlier': [ 7.65  9.35 12.02  8.84  8.57 10.78  7.64  8.23  7.97  8.87 10.44  7.91
#  11.32  8.15  8.93  9.9  11.73  8.37  9.06  8.4   8.38 11.24  7.66  8.86
#  10.33  9.96 11.48  8.32  8.34  8.95  7.73 10.04  8.8  11.64  8.12  8.08
#   9.05 10.11  9.82  9.09 11.94 11.07 10.18 10.75  9.63 11.87  7.67  8.54
#   7.61 11.45  8.66 10.26  8.47  8.49  9.71 10.42  8.14  8.69  9.51  8.21
#  11.4  10.33]

# %%
columns = ['troponin']

for column in columns:
    column_data = df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # find outlier
    outliers = column_data[(column_data < lower) | (column_data > upper)]

    # remove outlier
    df_no_outliers = df[(column_data >= lower) & (column_data <= upper)]
columns = ['troponin']
outlier_percentage = {}

for column in columns:
    column_data = df_no_outliers[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower) | (column_data > upper)]
    outlier_percentage[column] = len(outliers) / len(column_data) * 100

# Display the outlier percentage for each column
for column, percentage in outlier_percentage.items():
    print(f"Count of outliers in column '{column}': {len(outliers)}")
    print(f"Percentage of outliers in column '{column}':{percentage:.2f}%")
    print()
    print(f"Lower : {lower}")
    print(f"Upper : {upper}")
    print()
    print(f"Data Outlier': {np.array(outliers)}")
# Out:
# Count of outliers in column 'troponin': 135
# Percentage of outliers in column 'troponin':12.71%
#
# Lower : -0.021999999999999995
# Upper : 0.049999999999999996
#
# Data Outlier': [0.122 0.146 0.053 0.067 0.076 0.052 0.089 0.085 0.105 0.071 0.103 0.051
#  0.061 0.094 0.076 0.054 0.178 0.106 0.063 0.164 0.142 0.051 0.171 0.097
#  0.103 0.068 0.061 0.2   0.07  0.112 0.188 0.106 0.179 0.145 0.095 0.095
#  0.089 0.068 0.081 0.053 0.117 0.068 0.076 0.098 0.053 0.094 0.062 0.052
#  0.053 0.177 0.096 0.187 0.203 0.058 0.085 0.138 0.058 0.101 0.145 0.196
#  0.179 0.119 0.192 0.1   0.154 0.191 0.165 0.106 0.2   0.122 0.099 0.13
#  0.136 0.142 0.051 0.067 0.075 0.082 0.05  0.076 0.114 0.05  0.087 0.069
#  0.094 0.188 0.179 0.077 0.109 0.099 0.065 0.129 0.141 0.058 0.193 0.104
#  0.096 0.054 0.116 0.068 0.152 0.076 0.088 0.104 0.059 0.06  0.074 0.147
#  0.083 0.081 0.086 0.078 0.053 0.088 0.088 0.08  0.128 0.053 0.057 0.119
#  0.06  0.066 0.067 0.055 0.092 0.057 0.065 0.051 0.072 0.197 0.11  0.068
#  0.052 0.062 0.172]

# %%
data.head()
# Out:
#    age  gender  impluse  pressurehight  pressurelow  glucose    kcm  troponin  \
# 0   64       1       66            160           83    160.0   1.80     0.012
# 1   21       1       94             98           46    296.0   6.75     1.060
# 2   55       1       64            160           77    270.0   1.99     0.003
# 3   64       1       70            120           55    270.0  13.87     0.122
# 4   55       1       64            112           65    300.0   1.08     0.003
#
#       class
# 0  negative
# 1  positive
# 2  negative
# 3  positive
# 4  negative

# %%
# numeric_cols = data.select_dtypes(include='number').columns

# for col in numeric_cols:
#     plt.figure(figsize=(8, 4))
#     sns.boxplot(x=data[col])
#     plt.title(f'Boxplot of {col}')
#     plt.show()

# %%
# for col in numeric_cols:
#     plt.figure(figsize=(8, 4))
#     sns.scatterplot(x=data.index, y=data[col])
#     plt.xlabel('Index')
#     plt.ylabel(col)
#     plt.title(f'Scatter Plot of {col} vs Index')
#     plt.show()

# %%
# for col in numeric_cols:
#     plt.figure(figsize=(8, 4))
#     plt.hist(data[col], bins=30, edgecolor='k', alpha=0.7)
#     plt.title(f'Histogram of {col}')
#     plt.xlabel(col)
#     plt.ylabel('Frequency')
#     plt.show()

# %% [markdown]
# ### **Imputation Outlier**

# %%
# import numpy as np
# import pandas as pd

# # Make a copy of the dataset
# df_median = data.copy()

# # Select numeric columns only for outlier handling
# numeric_cols = df_median.select_dtypes(include=np.number).columns

# for column in numeric_cols:
#     column_data = df_median[column]

#     # Calculate Q1, Q3 and IQR
#     Q1 = np.percentile(column_data, 25)
#     Q3 = np.percentile(column_data, 75)
#     IQR = Q3 - Q1

#     lower = Q1 - 1.75 * IQR
#     upper = Q3 + 1.75 * IQR

#    # Calculate median
#     median = column_data.median()

#     # Find outliers
#     outlier_mask = (column_data < lower) | (column_data > upper)
#     outliers = column_data[outlier_mask]

 
#     # Replace outliers with median
#     df_median.loc[outlier_mask, column] = median

#     # Calculate outlier percentage
#     outlier_percentage = len(outliers) / len(column_data) * 100

#     # Print results for the column
#     print(f"Column: {column}")
#     print(f" - Outliers count: {len(outliers)}")
#     print(f" - Outliers percentage: {outlier_percentage:.2f}%")
#     print(f" - Lower bound: {lower}")
#     print(f" - Upper bound: {upper}")
#     print(f" - Replaced outliers with median value: {median}")
#     print(f" - Outlier values: {outliers.values}\n")
